# %% [markdown]
# # Quantum k-means Clustering on local quantum simulator
#
# To run this program, please follow these steps:
# * Download the file.
# * Install Qiskit, following this instruction: https://docs.quantum.ibm.com/start/install#local
# * Install sklearn using this command: `pip install scikit-learn`
# * Restart Kernel and Run All Cells

# %%
from qiskit import QuantumCircuit, QuantumRegister, ClassicalRegister
from qiskit.primitives import StatevectorSampler
from qiskit.transpiler.preset_passmanagers import generate_preset_pass_manager
from qiskit_ibm_runtime import QiskitRuntimeService, SamplerV2 as Sampler

import numpy as np
import math
import random
import itertools
import ast

import matplotlib.pyplot as plt
import pandas as pd

from sklearn.datasets import load_iris
from sklearn.preprocessing import MinMaxScaler
from sklearn.decomposition import PCA
from sklearn.model_selection import train_test_split
from sklearn.cluster import KMeans

"""
Construct functions for changing Cartesian coordinate to Polar coordinate
"""
def polar_angle(point):
    """
    Calculating polar angle
    """
    polar_angle = math.atan2(point[1], point[0])
    return polar_angle

def polar_radius(point):
    """
    Calculating polar coordinate
    """
    polar_radius = math.sqrt(point[0] ** 2 + point[1] ** 2)
    return polar_radius

def initialize_clusters(k, dataset):
    clusters = {}
    # Randomly choose k points from the dataset as centroids
    centroids = random.sample(dataset, k)
    # Create a dictionary to store points in the cluster represented by centroids
    for centroid in centroids:
        clusters[f"{centroid}"] = []
    return clusters, centroids

def recompute_centroids(clusters, centroids):
    """
    Construct function for recomputing centroids as the average of values in the clusters
    """
    is_equal = True
    new_clusters = {}
    new_centroids = []
    for old_centroids_string, cluster in clusters.items():
        old_centroid = ast.literal_eval(old_centroids_string)
        if len(cluster) > 0:
            new_centroid = np.mean(cluster, axis=0).tolist()
            if new_centroid != old_centroid:
                is_equal = False
            new_clusters[f"{new_centroid}"] = []
            new_centroids.append(new_centroid)
    if is_equal == False:
        return new_clusters, new_centroids, is_equal
    else:
        return clusters, centroids, is_equal

def quantum_circuit(qc, qr, cr, i, data_angle, centroid_angle):
    qc.h(qr[i * 2])
    qc.cx(qr[i * 2], qr[i * 2 + 1])
    qc.ry(-abs(data_angle - centroid_angle), qr[i * 2 + 1])
    qc.cx(qr[i * 2], qr[i * 2 + 1])
    qc.ry(abs(data_angle - centroid_angle), qr[i * 2 + 1])
    # Inteferernce and measurement
    qc.h(qr[i * 2])
    qc.measure(qr[i * 2], cr[i])
    return qc

def nearest_centroids_dictionary(dataset):
    """
    Construct a dictionary to store the information on nearest centroid for each point in the dataset
    """
    nearest_centroids_dict = {}
    for data_point in dataset:
        nearest_centroids_dict[f"{data_point}"] = {
            'smallest distance': float('inf'),
            'nearest centroid': None
        }
    return nearest_centroids_dict

def khan_quantum_distance(calculated_distances, nearest_centroids_dict, num_shots=1024):
    for idx, item in calculated_distances.items():
        probability_1 = item['count 1'] / num_shots
        cen = item['pair'][0]
        data = item['pair'][1]
        # Calculate the distance from probability of |1>
        normalize_value = math.sqrt(data[0] ** 2 + data[1] ** 2 + cen[0] ** 2 + cen[1] ** 2)
        quantum_dist = normalize_value * math.sqrt(2 * probability_1)
        # Compare with classical distance
        classical_dist = classical_distance(data, cen)
        print(f"Khan quantum distance - {quantum_dist} - Classical distance - {classical_dist}")
        # Update the nearest centroids dictionary
        if quantum_dist < nearest_centroids_dict[f"{data}"]['smallest distance']:
            nearest_centroids_dict[f"{data}"]['smallest distance'] = quantum_dist
            nearest_centroids_dict[f"{data}"]['nearest centroid'] = cen
    return nearest_centroids_dict

def duong_quantum_distance(calculated_distances, nearest_centroids_dict, num_shots=1024):
    for idx, item in calculated_distances.items():
        probability_1 = item['count 1'] / num_shots
        cen = item['pair'][0]
        data = item['pair'][1]
        # Calculate the distance from the probability of |1>
        data_radius = polar_radius(data)
        centroid_radius = polar_radius(cen)
        quantum_dist = math.sqrt((data_radius - centroid_radius) ** 2 + 4 * data_radius * centroid_radius * probability_1)
        # Compare with classical distance
        classical_dist = classical_distance(data, cen)
        print(f"Duong quantum distance - {quantum_dist} - Classical distance - {classical_dist}")
        # Update the nearest centroids dictionary
        if quantum_dist < nearest_centroids_dict[f"{data}"]['smallest distance']:
            nearest_centroids_dict[f"{data}"]['smallest distance'] = quantum_dist
            nearest_centroids_dict[f"{data}"]['nearest centroid'] = cen
    return nearest_centroids_dict

def classical_distance(point_1, point_2):
    """
    Classically calculate the Euclidean distance between 2 points
    """
    euclidean_distance = math.sqrt((point_1[0] - point_2[0]) ** 2 + (point_1[1] - point_2[1]) ** 2)
    return euclidean_distance

def classical_selection(dataset, centroids):
    nearest_centroids_dict = nearest_centroids_dictionary(dataset)
    for data in dataset:
        for centroid in centroids:
            classical_dist = classical_distance(data, centroid)
            if classical_dist < nearest_centroids_dict[f"{data}"]['smallest distance']:
                nearest_centroids_dict[f"{data}"]['smallest distance'] = classical_dist
                nearest_centroids_dict[f"{data}"]['nearest centroid'] = centroid
    return nearest_centroids_dict

def khan_quantum_selection(dataset, centroids, num_qubits, num_shots=1024):
    # Calculate the number of distances can be calculated at the same time
    num_distances = 0
    num_distances, remainder = divmod(num_qubits, 2)
    # Initialize the dictionary contains information about nearest centroids for each data point
    nearest_centroids_dict = nearest_centroids_dictionary(dataset)
    # Initialize a list contains all pairs of points in the data point
    pairs = []
    for centroid in centroids:
        for data in dataset:
            pairs.append([centroid, data])
    # Loop until all pairs' distances are calculated
    while len(pairs) > 0:
        # Initialize quantum circuit
        qr = QuantumRegister(num_distances * 2, name='q')
        cr = ClassicalRegister(num_distances, name='c')
        qc = QuantumCircuit(qr, cr)
        # Initialize dictionary contains all pairs of points whose distances are going to be calculated
        calculated_distances = {}
        i = 0
        # Loop until the circuit is full
        while (len(calculated_distances) < num_distances) and (len(pairs) > 0):
            pair = pairs.pop()
            centroid = pair[0]
            data_point = pair[1]
            centroid_angle = polar_angle(centroid)
            data_angle = polar_angle(data_point)
            qc = quantum_circuit(qc, qr, cr, i, data_angle, centroid_angle)
            # Update the index and calculated_distances
            calculated_distances[i] = {'pair': pair, 'count 1': 0}
            i += 1
        sampler = StatevectorSampler()
        job = sampler.run([qc], shots=num_shots)
        result = job.result()[0]
        count = result.data.c.get_counts()
        state_list = list(count.keys())
        for state in state_list:
            state_count = count.get(state, 0)
            for idx, bit in enumerate(state):
                if bit == '1':
                    if (len(calculated_distances) - idx - 1) >= 0:
                        calculated_distances[len(calculated_distances) - idx - 1]['count 1'] += state_count
        nearest_centroids_dict = khan_quantum_distance(calculated_distances, nearest_centroids_dict, num_shots)
    return nearest_centroids_dict

def duong_quantum_selection(dataset, centroids, num_qubits, num_shots=1024):
    # Calculate the number of distances can be calculated at the same time
    num_distances = 0
    num_distances, remainder = divmod(num_qubits, 2)
    # Initialize the dictionary contains information about nearest centroids for each data point
    nearest_centroids_dict = nearest_centroids_dictionary(dataset)
    # Initialize a list contains all pairs of points in the data point
    pairs = []
    for centroid in centroids:
        for data in dataset:
            pairs.append([centroid, data])
    # Loop until all pairs' distances are calculated
    while len(pairs) > 0:
        # Initialize quantum circuit
        qr = QuantumRegister(num_distances * 2, name='q')
        cr = ClassicalRegister(num_distances, name='c')
        qc = QuantumCircuit(qr, cr)
        # Initialize dictionary contains all pairs of points whose distances are going to be calculated
        calculated_distances = {}
        i = 0
        # Loop until the circuit is full
        while (len(calculated_distances) < num_distances) and (len(pairs) > 0):
            pair = pairs.pop()
            centroid = pair[0]
            data_point = pair[1]
            centroid_angle = polar_angle(centroid)
            data_angle = polar_angle(data_point)
            qc = quantum_circuit(qc, qr, cr, i, data_angle, centroid_angle)
            # Update the index and calculated_distances
            calculated_distances[i] = {'pair': pair, 'count 1': 0}
            i += 1
        sampler = StatevectorSampler()
        job = sampler.run([qc], shots=num_shots)
        result = job.result()[0]
        count = result.data.c.get_counts()
        state_list = list(count.keys())
        for state in state_list:
            state_count = count.get(state, 0)
            for idx, bit in enumerate(state):
                if bit == '1':
                    if (len(calculated_distances) - idx - 1) >= 0:
                        calculated_distances[len(calculated_distances) - idx - 1]['count 1'] += state_count
        nearest_centroids_dict = duong_quantum_distance(calculated_distances, nearest_centroids_dict, num_shots)
    return nearest_centroids_dict

def khan_quantum_clustering(k, dataset, clusters, centroids, num_qubits, duong_iteration, num_shots=1024):
    is_convergence = False
    iteration_count = 0
    repeated_point = [0.34600960858349594, -0.15629187416923862]
    # Loop until convergence
    while (not is_convergence) and (iteration_count < duong_iteration):
        iteration_count += 1
        # Run Khan's quantum program
        khan_dict = khan_quantum_selection(dataset, centroids, num_qubits, num_shots)
        classical_dict = classical_selection(dataset, centroids)
        # Compare Khan's choice with classical choice
        same_count = 0
        different_count = 0
        for data_string, data_dict in khan_dict.items():
            # Count the number of times Khan and Classical methods chose the same (different) centroids
            if data_dict['nearest centroid'] == classical_dict[data_string]['nearest centroid']:
                same_count += 1
            else:
                different_count += 1
            # Read and update the information to the clusters dictionary
            data = ast.literal_eval(data_string)
            nearest_centroid = data_dict['nearest centroid']
            clusters[f"{nearest_centroid}"].append(data)
        print(f"Khan same count: {same_count} and different count: {different_count}")
        # Add the repeated point to the clusters dictionary
        for centroid_string, cluster in clusters.items():
            if repeated_point in cluster:
                cluster.append(repeated_point)
        # Check if enough clusters have been created
        is_k_clusters = True
        for centroid_string, cluster in clusters.items():
            if len(cluster) == 0:
                is_k_clusters = False
        # If not enough clusters, repeat the upper task with another k randomly generated centroids
        if is_k_clusters == False:
            clusters, centroids = initalize_clusters(k, dataset)
            continue
        else:
            # Recompute centroids by averaging all points
            new_clusters, new_centroids, is_equal = recompute_centroids(clusters, centroids)
            if is_equal == True:
                is_convergence = True
                break
            else:
                clusters = new_clusters
                centroids = new_centroids
    print(f"Khan's iteration count is: {iteration_count}")
    return clusters, centroids

def duong_quantum_clustering(k, dataset, clusters, centroids, num_qubits, num_shots=1024):
    is_convergence = False
    iteration_count = 0
    repeated_point = [0.34600960858349594, -0.15629187416923862]
    # Loop until convergence
    while not is_convergence:
        iteration_count += 1
        # Run Duong's quantum program
        duong_dict = duong_quantum_selection(dataset, centroids, num_qubits, num_shots)
        classical_dict = classical_selection(dataset, centroids)
        # Compare Duong's choice with classical choice
        same_count = 0
        different_count = 0
        for data_string, data_dict in duong_dict.items():
            # Count the number of times Duong and Classical methods chose the same (different) centroids
            if data_dict['nearest centroid'] == classical_dict[data_string]['nearest centroid']:
                same_count += 1
            else:
                different_count += 1
            # Read and update the information to the clusters dictionary
            data = ast.literal_eval(data_string)
            nearest_centroid = data_dict['nearest centroid']
            clusters[f"{nearest_centroid}"].append(data)
        print(f"Duong same count: {same_count} and different count: {different_count}")
        # Add the repeated point to the clusters dictionary
        for centroid_string, cluster in clusters.items():
            if repeated_point in cluster:
                cluster.append(repeated_point)
        # Check if enough clusters have been created
        is_k_clusters = True
        for centroid_string, cluster in clusters.items():
            if len(cluster) == 0:
                is_k_clusters = False
        # If not enough clusters, repeat the upper task with another k randomly generated centroids
        if is_k_clusters == False:
            clusters, centroids = initalize_clusters(k, dataset)
            continue
        else:
            # Recompute centroids by averaging all points
            new_clusters, new_centroids, is_equal = recompute_centroids(clusters, centroids)
            if is_equal == True:
                is_convergence = True
                break
            else:
                clusters = new_clusters
                centroids = new_centroids
    print(f"Duong's iteration count is: {iteration_count}")
    return clusters, centroids, iteration_count

def run_program(k, dataset, correct_clusters, num_qubits, num_shots=1024):
    # Initialize empty clusters with randomly chosen centroids
    clusters, centroids = initialize_clusters(k, dataset)
    print(f"Original centroids {centroids}")
    duong_clusters, duong_centroids, duong_iteration = duong_quantum_clustering(k, dataset, clusters, centroids, num_qubits, num_shots)
    khan_clusters, khan_centroids = khan_quantum_clustering(k, dataset, clusters, centroids, num_qubits, duong_iteration, num_shots)
    # Create plot
    fig, axes = plt.subplots(1, 3, figsize=(18, 6))
    # Khan plot
    ax1 = axes[0]
    # Plot original centroids
    for centroid in centroids:
        ax1.scatter(centroid[0], centroid[1], marker='o', s=100, color='black')
    for centroid_string, cluster in khan_clusters.items():
        # Plot centroid
        centroid = ast.literal_eval(centroid_string)
        ax1.scatter(centroid[0], centroid[1], marker='x', s=100, color='black')
        # Plot points
        x_values = []
        y_values = []
        for point in cluster:
            x_values.append(point[0])
            y_values.append(point[1])
        ax1.scatter(x_values, y_values)
    ax1.set_xlabel('Feature 1')
    ax1.set_ylabel('Feature 2')
    ax1.set_title('Khan et al. result')
    # Duong plot
    ax2 = axes[1]
    # Plot original centroids
    for centroid in centroids:
        ax2.scatter(centroid[0], centroid[1], marker='o', s=100, color='black')
    for centroid_string, cluster in duong_clusters.items():
        # Plot centroids
        centroid = ast.literal_eval(centroid_string)
        ax2.scatter(centroid[0], centroid[1], marker='x', s=100, color='black')
        # Plot points
        x_values = []
        y_values = []
        for point in cluster:
            x_values.append(point[0])
            y_values.append(point[1])
        ax2.scatter(x_values, y_values)
    ax2.set_xlabel('Feature 1')
    ax2.set_ylabel('Feature 2')
    ax2.set_title('New method result')
    # Correct labels plot
    ax3 = axes[2]
    # Plot original centroids
    for centroid in centroids:
        ax3.scatter(centroid[0], centroid[1], marker='o', s=100, color='black')
    for centroid_string, cluster in correct_clusters.items():
        # Plot centroids
        centroid = ast.literal_eval(centroid_string)
        ax3.scatter(centroid[0], centroid[1], marker='x', s=100, color='black')
        # Plot points
        x_values = []
        y_values = []
        for point in cluster:
            x_values.append(point[0])
            y_values.append(point[1])
        ax3.scatter(x_values, y_values)
    ax3.set_xlabel('Feature 1')
    ax3.set_ylabel('Feature 2')
    ax3.set_title('Correct labels')
    # Save the plot to a file
    plt.savefig("k_means_compare1.png")
    return duong_clusters, khan_clusters, correct_clusters

# Import Iris dataset
iris_data = load_iris()
features = iris_data.data
labels = iris_data.target
# Apply MinMaxScaler to map data onto (0, 1)
features = MinMaxScaler().fit_transform(features)
# Reduce the number of features
features = PCA(n_components=2).fit_transform(features)
# Change features to list and create list which store correct labels
data_list = features.tolist()
correct_list = labels.tolist()
# Create a clusters dictionary from the information obtained above
correct_clusters = {0: [], 1: [], 2: []}
for i, label in enumerate(correct_list):
    if label == 0:
        correct_clusters[0].append(data_list[i])
    elif label == 1:
        correct_clusters[1].append(data_list[i])
    else:
        correct_clusters[2].append(data_list[i])
# Change the dictionary keys to centroids
new_correct_clusters = {}
for i, cluster in correct_clusters.items():
    centroid = np.mean(cluster, axis=0).tolist()
    new_correct_clusters[f"{centroid}"] = cluster
correct_clusters = new_correct_clusters
# Run the experiment
duong_clusters, khan_clusters, correct_clusters = run_program(3, data_list, correct_clusters, 10, 2048)
# Out:
# Original centroids [[0.1450335378193761, -0.07639613445205201], [-0.6389431903256223, 0.03259883747055303], [0.06697266073446895, -0.1681323432736022]]
# Duong quantum distance - 0.2863550702691988 - Classical distance - 0.28078539761702703
# Duong quantum distance - 0.5244930875129602 - Classical distance - 0.5276760101550746
# Duong quantum distance - 0.431876987318796 - Classical distance - 0.4322482448716871
# Duong quantum distance - 0.3503721885825936 - Classical distance - 0.34019383341766773
# Duong quantum distance - 0.5360120164363578 - Classical distance - 0.5354452085178076
# Duong quantum distance - 0.6614018071112984 - Classical distance - 0.662618641516944
# Duong quantum distance - 0.6339506675913917 - Classical distance - 0.636300569511956
# Duong quantum distance - 0.27758827283859117 - Classical distance - 0.27928805018029684
# Duong quantum distance - 0.5710179658078839 - Classical distance - 0.5706537768646182
# Duong quantum distance - 0.610757016385322 - Classical distance - 0.6060386333905801
# Duong quantum distance - 0.5439037925002149 - Classical distance - 0.5502415998376925
# Duong quantum distance - 0.27233603502190257 - Classical distance - 0.2719005900813815
# Duong quantum distance - 0.41317197878130646 - Classical distance - 0.4098038439586968
# Duong quantum distance - 0.5761136647956688 - Classical distance - 0.5815500161192507
# Duong quantum distance - 0.774447233815145 - Classical distance - 0.7734803738476226
# Duong quantum distance - 0.23804141105759052 - Classical distance - 0.23852267001800193
# Duong quantum distance - 0.24926115012098898 - Classical distance - 0.2496622894691666
# Duong quantum distance - 0.4890763653971445 - Classical distance - 0.4898918507875641
# Duong quantum distance - 0.9054432707580711 - Classical distance - 0.9053924902036822
# Duong quantum distance - 0.6055257281315769 - Classical distance - 0.6100242356422189
# Duong quantum distance - 0.5078022213484856 - Classical distance - 0.5049390507802652
# Duong quantum distance - 0.465019405721573 - Classical distance - 0.46386539207957955
# Duong quantum distance - 0.30336981871127255 - Classical distance - 0.2963716472376332
# Duong quantum distance - 0.2780854527728729 - Classical distance - 0.2801883050445671
# Duong quantum distance - 0.5961028465318808 - Classical distance - 0.5975672047814007
# Duong quantum distance - 0.5716763211393059 - Classical distance - 0.5733268684119458
# Duong quantum distance - 0.30661216381315276 - Classical distance - 0.2993198760474806
# Duong quantum distance - 0.7409528574226749 - Classical distance - 0.736978013845712
# Duong quantum distance - 0.2521740674988004 - Classical distance - 0.2566529147857339
# Duong quantum distance - 0.6363120077570527 - Classical distance - 0.6352412350224323
# Duong quantum distance - 0.2636675050259504 - Classical distance - 0.26314542414740727
# Duong quantum distance - 0.820560645157698 - Classical distance - 0.8245468808230648
# Duong quantum distance - 0.9291826786397266 - Classical distance - 0.929789215707334
# Duong quantum distance - 0.40853111086010274 - Classical distance - 0.41150530092148974
# Duong quantum distance - 0.522660516716867 - Classical distance - 0.520643522932737
# Duong quantum distance - 0.4108361275736886 - Classical distance - 0.4100297662231479
# Duong quantum distance - 0.30441175918104263 - Classical distance - 0.3055099393137759
# Duong quantum distance - 0.5361238933513177 - Classical distance - 0.5300025528594675
# Duong quantum distance - 0.3807306998934794 - Classical distance - 0.37935316155697196
# Duong quantum distance - 0.46190606259268885 - Classical distance - 0.455099056074814
# Duong quantum distance - 0.8230763157936655 - Classical distance - 0.8245968443463652
# Duong quantum distance - 0.4451935850227599 - Classical distance - 0.4454688424984565
# Duong quantum distance - 0.5950230623785724 - Classical distance - 0.5975399657457637
# Duong quantum distance - 0.17631920286204908 - Classical distance - 0.1763413172136668
# Duong quantum distance - 0.7511338304654778 - Classical distance - 0.7544960175891344
# Duong quantum distance - 0.5277632819254775 - Classical distance - 0.5349337679173229
# Duong quantum distance - 0.3869353305625092 - Classical distance - 0.37818198774881356
# Duong quantum distance - 0.6065372010487733 - Classical distance - 0.6130172272770799
# Duong quantum distance - 0.27295669618984303 - Classical distance - 0.27928805018029684
# Duong quantum distance - 0.6217197636848759 - Classical distance - 0.6245820608204145
# Duong quantum distance - 0.04890744423338263 - Classical distance - 0.05068396916711619
# Duong quantum distance - 0.25251615096879576 - Classical distance - 0.25601062621775356
# Duong quantum distance - 0.1599193718463114 - Classical distance - 0.16031058819137683
# Duong quantum distance - 0.08633158550903437 - Classical distance - 0.08708952576743839
# Duong quantum distance - 0.12947344752514314 - Classical distance - 0.12968247737525695
# Duong quantum distance - 0.0 - Classical distance - 0.0
# Duong quantum distance - 0.3015054402531461 - Classical distance - 0.3049604950209072
# Duong quantum distance - 0.022150365722743405 - Classical distance - 0.021387249782812465
# Duong quantum distance - 0.20413109680290556 - Classical distance - 0.19957457963199288
# Duong quantum distance - 0.05471826550912201 - Classical distance - 0.05234485742700921
# Duong quantum distance - 0.08706097749610524 - Classical distance - 0.08738985472844965
# Duong quantum distance - 0.1182360028957849 - Classical distance - 0.11772101691210589
# Duong quantum distance - 0.14698474541442177 - Classical distance - 0.14665518638111097
# Duong quantum distance - 0.343742143689277 - Classical distance - 0.345705339169854
# Duong quantum distance - 0.3251267555684246 - Classical distance - 0.32735467685595415
# Duong quantum distance - 0.09251308605859301 - Classical distance - 0.09565023263706911
# Duong quantum distance - 0.21395793958782877 - Classical distance - 0.2249284294660504
# Duong quantum distance - 0.04557236543515402 - Classical distance - 0.04390762242461231
# Duong quantum distance - 0.17237283034452397 - Classical distance - 0.17282880090368793
# Duong quantum distance - 0.14495249154792883 - Classical distance - 0.14900323119247197
# Duong quantum distance - 0.1354388128748979 - Classical distance - 0.1368678216032792
# Duong quantum distance - 0.17498149821507333 - Classical distance - 0.16847741028591326
# Duong quantum distance - 0.3796817317667551 - Classical distance - 0.38125802543589804
# Duong quantum distance - 0.28376786497564926 - Classical distance - 0.28327589609438525
# Duong quantum distance - 0.26919959511776154 - Classical distance - 0.2713550493440291
# Duong quantum distance - 0.19715515969566466 - Classical distance - 0.1920010847017733
# Duong quantum distance - 0.12646566098461617 - Classical distance - 0.12045344553069476
# Duong quantum distance - 0.21713087297991882 - Classical distance - 0.22211618610495956
# Duong quantum distance - 0.09794356217630304 - Classical distance - 0.10351159799715764
# Duong quantum distance - 0.2934484724703952 - Classical distance - 0.2947509250533886
# Duong quantum distance - 0.09853458634293867 - Classical distance - 0.10184141244003733
# Duong quantum distance - 0.22492414363488766 - Classical distance - 0.22341716546492657
# Duong quantum distance - 0.06409121989389466 - Classical distance - 0.07229525504441056
# Duong quantum distance - 0.12741096136579552 - Classical distance - 0.12767011920017843
# Duong quantum distance - 0.31568003581677634 - Classical distance - 0.3166629807582774
# Duong quantum distance - 0.10922483162208807 - Classical distance - 0.11089479129803081
# Duong quantum distance - 0.17475521187314863 - Classical distance - 0.1797368653910274
# Duong quantum distance - 0.1416861911647189 - Classical distance - 0.13992702419124828
# Duong quantum distance - 0.16817671379938676 - Classical distance - 0.16337727478496977
# Duong quantum distance - 0.3730361322464827 - Classical distance - 0.3725452094672596
# Duong quantum distance - 0.06813940530532939 - Classical distance - 0.0680844075661513
# Duong quantum distance - 0.24241060970555597 - Classical distance - 0.23943213483567277
# Duong quantum distance - 0.2994394705543703 - Classical distance - 0.30174606099133106
# Duong quantum distance - 0.34850764599975764 - Classical distance - 0.35043496248304223
# Duong quantum distance - 0.057651253548927146 - Classical distance - 0.05921924114894911
# Duong quantum distance - 0.22747345321586995 - Classical distance - 0.2396531429835845
# Duong quantum distance - 0.16075164862241065 - Classical distance - 0.160548480688337
# Duong quantum distance - 0.3904314806989298 - Classical distance - 0.3904782305344159
# Duong quantum distance - 0.3185476494674401 - Classical distance - 0.315445371536618
# Duong quantum distance - 0.4090768002277913 - Classical distance - 0.4074698356516527
# Duong quantum distance - 0.7220437441445527 - Classical distance - 0.7219920976531311
# Duong quantum distance - 0.7726424681374199 - Classical distance - 0.7724957029546649
# Duong quantum distance - 0.7499804204774695 - Classical distance - 0.7451362391676764
# Duong quantum distance - 0.7944947066150388 - Classical distance - 0.7958672576233079
# Duong quantum distance - 0.6784991316354378 - Classical distance - 0.6767560479958824
# Duong quantum distance - 0.7211509110877738 - Classical distance - 0.7205587348102078
# Duong quantum distance - 0.637211513178415 - Classical distance - 0.6366086086522399
# Duong quantum distance - 0.78295321087953 - Classical distance - 0.7761900630968611
# Duong quantum distance - 0.7161208142981768 - Classical distance - 0.7200618444488687
# Duong quantum distance - 0.7440126405937016 - Classical distance - 0.7418048529083182
# Duong quantum distance - 0.720619977765995 - Classical distance - 0.7210208231395303
# Duong quantum distance - 0.7546825344399134 - Classical distance - 0.7593671898605014
# Duong quantum distance - 0.805859353180874 - Classical distance - 0.8083821263742399
# Duong quantum distance - 0.7370215957160586 - Classical distance - 0.735943961701571
# Duong quantum distance - 0.731615450745061 - Classical distance - 0.7277915640740273
# Duong quantum distance - 0.6929861580511777 - Classical distance - 0.6930413020847761
# Duong quantum distance - 0.9094843218609427 - Classical distance - 0.9088912802252825
# Duong quantum distance - 0.9037700565692062 - Classical distance - 0.9003525011552334
# Duong quantum distance - 0.6477399464253499 - Classical distance - 0.6510295522905745
# Duong quantum distance - 0.6914574203940912 - Classical distance - 0.692651322791351
# Duong quantum distance - 0.7139970444115392 - Classical distance - 0.7142563955879726
# Duong quantum distance - 0.7253548781629539 - Classical distance - 0.7240466403241909
# Duong quantum distance - 0.7322286752166288 - Classical distance - 0.7336553343134358
# Duong quantum distance - 0.6659341941181667 - Classical distance - 0.6670311505926435
# Duong quantum distance - 0.6670656653113095 - Classical distance - 0.6612896664959749
# Duong quantum distance - 0.7057410619319191 - Classical distance - 0.7029426104274608
# Duong quantum distance - 0.6028945574451128 - Classical distance - 0.6056833956657764
# Duong quantum distance - 0.8468647718234218 - Classical distance - 0.8453138272391304
# Duong quantum distance - 0.7310205808948601 - Classical distance - 0.7343268512974319
# Duong quantum distance - 0.6838189010064784 - Classical distance - 0.6805984916485988
# Duong quantum distance - 0.7802999423806403 - Classical distance - 0.7818262919169565
# Duong quantum distance - 0.74085933846355 - Classical distance - 0.7435196955547065
# Duong quantum distance - 0.7279998700563693 - Classical distance - 0.7250690820439122
# Duong quantum distance - 0.7905949560322882 - Classical distance - 0.7925072217564747
# Duong quantum distance - 0.9202445427465306 - Classical distance - 0.9221395886210348
# Duong quantum distance - 0.8634379213518931 - Classical distance - 0.8637484200859479
# Duong quantum distance - 0.8219111324797519 - Classical distance - 0.8189467817770236
# Duong quantum distance - 0.731850143384311 - Classical distance - 0.730476243573432
# Duong quantum distance - 0.7334511315507847 - Classical distance - 0.7339006715495194
# Duong quantum distance - 0.7662385490903869 - Classical distance - 0.7680143020265461
# Duong quantum distance - 0.7127757743818252 - Classical distance - 0.7197284962500723
# Duong quantum distance - 0.7372120088847144 - Classical distance - 0.743330098089403
# Duong quantum distance - 0.7289367914974432 - Classical distance - 0.7284584122614548
# Duong quantum distance - 0.7408508633734485 - Classical distance - 0.7452899700906365
# Duong quantum distance - 0.7578841748091386 - Classical distance - 0.7564607469937021
# Duong quantum distance - 0.7752261389259628 - Classical distance - 0.7767161510150015
# Duong quantum distance - 0.7207450598369555 - Classical distance - 0.7240712005452975
# Duong quantum distance - 0.7499717121972509 - Classical distance - 0.7456839003015048
# Duong quantum distance - 0.6915871546333769 - Classical distance - 0.6928281208679183
# Duong quantum distance - 0.7476878136022598 - Classical distance - 0.7501782293599005
# Duong quantum distance - 0.9525670063935736 - Classical distance - 0.9531424381475091
# Duong quantum distance - 1.1325233685368454 - Classical distance - 1.1332150233625784
# Duong quantum distance - 1.0856547818329427 - Classical distance - 1.0860971404559052
# Duong quantum distance - 1.0665252825857923 - Classical distance - 1.0658757205325846
# Duong quantum distance - 1.1895305765910942 - Classical distance - 1.1907164976476654
# Duong quantum distance - 1.2887213444021743 - Classical distance - 1.2846342173938916
# Duong quantum distance - 1.2677672658697574 - Classical distance - 1.2673019533563041
# Duong quantum distance - 1.0032611041682502 - Classical distance - 1.0029016487286742
# Duong quantum distance - 1.200045286549506 - Classical distance - 1.200622555802145
# Duong quantum distance - 1.254784372619766 - Classical distance - 1.2542635006636889
# Duong quantum distance - 1.180764246826809 - Classical distance - 1.1780456951590146
# Duong quantum distance - 0.9327629158534455 - Classical distance - 0.9327606946666835
# Duong quantum distance - 1.0457972013102128 - Classical distance - 1.0459205463695234
# Duong quantum distance - 1.1956647718170494 - Classical distance - 1.1934588629671943
# Duong quantum distance - 1.4049972562770916 - Classical distance - 1.4089901444175914
# Duong quantum distance - 0.9650059651755869 - Classical distance - 0.9641460665669997
# Duong quantum distance - 0.9346871692764299 - Classical distance - 0.9344989921431821
# Duong quantum distance - 1.1856954590633337 - Classical distance - 1.1856315660591303
# Duong quantum distance - 1.4035501375057393 - Classical distance - 1.403468576723488
# Duong quantum distance - 1.2718401360388054 - Classical distance - 1.272265557055709
# Duong quantum distance - 1.127137643982963 - Classical distance - 1.1268124134113282
# Duong quantum distance - 1.1580572679423378 - Classical distance - 1.158771417826117
# Duong quantum distance - 0.9541951728419327 - Classical distance - 0.9544905570109988
# Duong quantum distance - 0.9733117752635922 - Classical distance - 0.9728760889374067
# Duong quantum distance - 1.1947221826615626 - Classical distance - 1.1960195107440006
# Duong quantum distance - 1.178745991040237 - Classical distance - 1.177850989638287
# Duong quantum distance - 1.0025525805830233 - Classical distance - 1.0043243685618286
# Duong quantum distance - 1.3981231642101164 - Classical distance - 1.3980695450350797
# Duong quantum distance - 0.9758106391226897 - Classical distance - 0.9765411258248988
# Duong quantum distance - 1.2634109159452298 - Classical distance - 1.2594989125952474
# Duong quantum distance - 0.9920499399679158 - Classical distance - 0.9864799168130144
# Duong quantum distance - 1.5112974927833658 - Classical distance - 1.5113164778748571
# Duong quantum distance - 1.45263448777066 - Classical distance - 1.4534009727008157
# Duong quantum distance - 1.0646608422585073 - Classical distance - 1.0636174684716528
# Duong quantum distance - 1.1569316983232405 - Classical distance - 1.1547796620033333
# Duong quantum distance - 1.1228888867517601 - Classical distance - 1.1236928355336548
# Duong quantum distance - 1.0397733960515594 - Classical distance - 1.0393118649400075
# Duong quantum distance - 1.1812531512032165 - Classical distance - 1.18030915867013
# Duong quantum distance - 1.0836467615988679 - Classical distance - 1.0833783621246251
# Duong quantum distance - 1.0671782237109386 - Classical distance - 1.0661836305640644
# Duong quantum distance - 1.3914049683236918 - Classical distance - 1.3926858109970923
# Duong quantum distance - 1.1657327996398195 - Classical distance - 1.1617652652719068
# Duong quantum distance - 1.248895382859093 - Classical distance - 1.2489261710449835
# Duong quantum distance - 0.8563990094162331 - Classical distance - 0.8556460452482704
# Duong quantum distance - 1.3942359839536533 - Classical distance - 1.3941995460477352
# Duong quantum distance - 1.203053543833546 - Classical distance - 1.202566099990527
# Duong quantum distance - 1.05842803820304 - Classical distance - 1.0584056596616573
# Duong quantum distance - 1.257511277695661 - Classical distance - 1.2587634132978427
# Duong quantum distance - 1.0023149003869547 - Classical distance - 1.0029016487286742
# Duong quantum distance - 1.263731002820278 - Classical distance - 1.2645214950381314
# Duong quantum distance - 0.7198018661648984 - Classical distance - 0.7169225189091732
# Duong quantum distance - 0.5699139716688248 - Classical distance - 0.5781108432706037
# Duong quantum distance - 0.7765525294325913 - Classical distance - 0.7766360554373113
# Duong quantum distance - 0.7152228422231091 - Classical distance - 0.7142563955879726
# Duong quantum distance - 0.6755770778435717 - Classical distance - 0.6762084785572158
# Duong quantum distance - 0.7271028815761583 - Classical distance - 0.7339006715495194
# Duong quantum distance - 0.6350214624337124 - Classical distance - 0.6364191495082652
# Duong quantum distance - 0.7243262240766902 - Classical distance - 0.7200588084880558
# Duong quantum distance - 0.8153403107591659 - Classical distance - 0.8154633656611834
# Duong quantum distance - 0.7408480926031993 - Classical distance - 0.7386210104896198
# Duong quantum distance - 0.7383041137846516 - Classical distance - 0.7429429847504142
# Duong quantum distance - 0.682387340246888 - Classical distance - 0.6821606848940404
# Duong quantum distance - 0.8808330632491179 - Classical distance - 0.8775023018519867
# Duong quantum distance - 0.9214174731464398 - Classical distance - 0.9195943688683029
# Duong quantum distance - 0.828103425026135 - Classical distance - 0.8279780235165897
# Duong quantum distance - 0.7576956524256147 - Classical distance - 0.7574097897805896
# Duong quantum distance - 0.9411316144788394 - Classical distance - 0.9422578864451756
# Duong quantum distance - 0.6950616249026694 - Classical distance - 0.6934033789252698
# Duong quantum distance - 0.6471899490392152 - Classical distance - 0.6620186973726689
# Duong quantum distance - 0.6980621420177859 - Classical distance - 0.6956340672450028
# Duong quantum distance - 0.6079395512495043 - Classical distance - 0.6105157141425893
# Duong quantum distance - 0.8301311177669175 - Classical distance - 0.829800512035226
# Duong quantum distance - 1.007310383352296 - Classical distance - 1.0085920250659597
# Duong quantum distance - 0.9309327216091432 - Classical distance - 0.9312946605086352
# Duong quantum distance - 0.854377152604255 - Classical distance - 0.85334476380399
# Duong quantum distance - 0.7990614893471834 - Classical distance - 0.7988867147981389
# Duong quantum distance - 0.7926634472134232 - Classical distance - 0.7915171597491403
# Duong quantum distance - 0.9483814155384501 - Classical distance - 0.9497076979786847
# Duong quantum distance - 0.745625692583109 - Classical distance - 0.7448146872803183
# Duong quantum distance - 0.90646381093329 - Classical distance - 0.9072301908843446
# Duong quantum distance - 0.6838391083239007 - Classical distance - 0.6893408372952136
# Duong quantum distance - 0.950507325380902 - Classical distance - 0.9496921156522468
# Duong quantum distance - 0.6645878986847262 - Classical distance - 0.661911082056329
# Duong quantum distance - 0.7780780990884038 - Classical distance - 0.777632156372075
# Duong quantum distance - 0.8602494559274559 - Classical distance - 0.8618559899242363
# Duong quantum distance - 0.6404257745597605 - Classical distance - 0.6418590689670375
# Duong quantum distance - 0.8341481519925388 - Classical distance - 0.8346273032382404
# Duong quantum distance - 0.7658526449208218 - Classical distance - 0.7623377279048881
# Duong quantum distance - 0.778003198732357 - Classical distance - 0.7781184026768986
# Duong quantum distance - 0.7503153236114422 - Classical distance - 0.7437078325079388
# Duong quantum distance - 0.7097064493074073 - Classical distance - 0.6986684217695165
# Duong quantum distance - 0.8524787443833066 - Classical distance - 0.8532573070027847
# Duong quantum distance - 0.5949211067866412 - Classical distance - 0.6059242592141756
# Duong quantum distance - 0.8939877511645006 - Classical distance - 0.8895690353598883
# Duong quantum distance - 0.7557154032854767 - Classical distance - 0.7586480901402844
# Duong quantum distance - 0.9035855035598197 - Classical distance - 0.903600303871968
# Duong quantum distance - 0.7791672402560028 - Classical distance - 0.7861815524484854
# Duong quantum distance - 0.9660768436379491 - Classical distance - 0.9658270265744963
# Duong quantum distance - 0.857062436642103 - Classical distance - 0.8576161853498129
# Duong quantum distance - 0.932724793459937 - Classical distance - 0.9305231163368833
# Duong quantum distance - 0.00949651716432054 - Classical distance - 0.015085061021308837
# Duong quantum distance - 0.18371287870293113 - Classical distance - 0.1753365434311873
# Duong quantum distance - 0.09352398151154125 - Classical distance - 0.10192728330530444
# Duong quantum distance - 0.17730096944426124 - Classical distance - 0.186212446554628
# Duong quantum distance - 0.14060585831287867 - Classical distance - 0.15224259699616352
# Duong quantum distance - 0.21140422378460266 - Classical distance - 0.20553510578642484
# Duong quantum distance - 0.13800432436331483 - Classical distance - 0.13840159959325257
# Duong quantum distance - 0.1249622432246208 - Classical distance - 0.1363192517047415
# Duong quantum distance - 0.44324786927483467 - Classical distance - 0.44788088550817284
# Duong quantum distance - 0.049140145057467687 - Classical distance - 0.06512624576677802
# Duong quantum distance - 0.03540619996028134 - Classical distance - 0.04404908015283034
# Duong quantum distance - 0.1878655091406691 - Classical distance - 0.20181372661503666
# Duong quantum distance - 0.11020860685719303 - Classical distance - 0.10185926286836496
# Duong quantum distance - 0.12345913015995885 - Classical distance - 0.1310005201384845
# Duong quantum distance - 0.056983249880116514 - Classical distance - 0.048054217168809206
# Duong quantum distance - 0.09410806222193216 - Classical distance - 0.10223278407339023
# Duong quantum distance - 0.41168320828054317 - Classical distance - 0.3858297291510076
# Duong quantum distance - 0.3184758035623919 - Classical distance - 0.3139704324844446
# Duong quantum distance - 0.1379562303957903 - Classical distance - 0.13432118709456625
# Duong quantum distance - 0.11615731032835717 - Classical distance - 0.1145563162014501
# Duong quantum distance - 0.0938317397378074 - Classical distance - 0.08708952576743834
# Duong quantum distance - 0.05967902301799701 - Classical distance - 0.05568511967527221
# Duong quantum distance - 0.08583615409047957 - Classical distance - 0.09097265801571774
# Duong quantum distance - 0.07553088315564349 - Classical distance - 0.08067233186019102
# Duong quantum distance - 0.15306043273310205 - Classical distance - 0.13616890139099755
# Duong quantum distance - 0.03144957574831819 - Classical distance - 0.031485670165402706
# Duong quantum distance - 0.13290934035200563 - Classical distance - 0.13293074951204037
# Duong quantum distance - 0.10793930621874753 - Classical distance - 0.11458183173107958
# Duong quantum distance - 0.12750517946177356 - Classical distance - 0.16010591685611775
# Duong quantum distance - 0.11444129800268728 - Classical distance - 0.10694073232506078
# Duong quantum distance - 0.18720948442555008 - Classical distance - 0.18844914221909032
# Duong quantum distance - 0.29199114581489155 - Classical distance - 0.2811978279354949
# Duong quantum distance - 0.08718226341779452 - Classical distance - 0.08243572850222378
# Duong quantum distance - 0.24148316764907476 - Classical distance - 0.26834510672860407
# Duong quantum distance - 0.5232496316370111 - Classical distance - 0.4903975150927073
# Duong quantum distance - 0.34835680945410985 - Classical distance - 0.3497751095752888
# Duong quantum distance - 0.23216975358025743 - Classical distance - 0.23314108117485627
# Duong quantum distance - 0.12017991339617694 - Classical distance - 0.1499280691997884
# Duong quantum distance - 0.0 - Classical distance - 0.0
# Duong quantum distance - 0.20130929255766394 - Classical distance - 0.18916924912355507
# Duong quantum distance - 0.09054773507936384 - Classical distance - 0.10003157447661983
# Duong quantum distance - 0.24256118255741446 - Classical distance - 0.23617110866738616
# Duong quantum distance - 0.04123298819382134 - Classical distance - 0.027842559837636126
# Duong quantum distance - 0.03323330872539326 - Classical distance - 0.028072352347526724
# Duong quantum distance - 0.2677622796638108 - Classical distance - 0.2771375728297995
# Duong quantum distance - 0.10616396512270379 - Classical distance - 0.10136793833423284
# Duong quantum distance - 0.13371282269326742 - Classical distance - 0.13633475804110518
# Duong quantum distance - 0.0777201212015157 - Classical distance - 0.08940713873574138
# Duong quantum distance - 0.12590071567967448 - Classical distance - 0.13779521420579494
# Duong quantum distance - 0.03998708291154768 - Classical distance - 0.07543051926835131
# Duong quantum distance - 0.17901574901822453 - Classical distance - 0.17305761816981846
# Duong quantum distance - 0.40841614181276553 - Classical distance - 0.4109473502622695
# Duong quantum distance - 0.3226350048598775 - Classical distance - 0.32288682523428974
# Duong quantum distance - 0.2785014864538194 - Classical distance - 0.27894279668081456
# Duong quantum distance - 0.42766355000564926 - Classical distance - 0.42865422891213084
# Duong quantum distance - 0.5495306498055812 - Classical distance - 0.5503197029921731
# Duong quantum distance - 0.5237090565902692 - Classical distance - 0.525320020748774
# Duong quantum distance - 0.2163092795140908 - Classical distance - 0.21627461766176106
# Duong quantum distance - 0.45430693210347706 - Classical distance - 0.4584782122781727
# Duong quantum distance - 0.499748424901137 - Classical distance - 0.498496691372542
# Duong quantum distance - 0.4385303301287875 - Classical distance - 0.437314047985117
# Duong quantum distance - 0.15960982192002904 - Classical distance - 0.1592720752097181
# Duong quantum distance - 0.2990532660469312 - Classical distance - 0.29554617223838314
# Duong quantum distance - 0.466325084918914 - Classical distance - 0.46650353869427114
# Duong quantum distance - 0.6626515165317979 - Classical distance - 0.665079953026418
# Duong quantum distance - 0.18167814725811438 - Classical distance - 0.18167894479121452
# Duong quantum distance - 0.1455967639442822 - Classical distance - 0.14722753018983215
# Duong quantum distance - 0.3995087822418108 - Classical distance - 0.3990601800114045
# Duong quantum distance - 0.7821360224228284 - Classical distance - 0.7851131007924994
# Duong quantum distance - 0.5054191242911175 - Classical distance - 0.5065057304372943
# Duong quantum distance - 0.3895334270254285 - Classical distance - 0.39016077852994835
# Duong quantum distance - 0.37305523033326243 - Classical distance - 0.37222458155249843
# Duong quantum distance - 0.18097673225700264 - Classical distance - 0.1839325397622201
# Duong quantum distance - 0.18472952285418404 - Classical distance - 0.1838575659167493
# Duong quantum distance - 0.48154926022382766 - Classical distance - 0.4809914262522866
# Duong quantum distance - 0.4558239621921988 - Classical distance - 0.45715659332351904
# Duong quantum distance - 0.21364358234371902 - Classical distance - 0.21302061855809162
# Duong quantum distance - 0.6375172529956975 - Classical distance - 0.6346442173232807
# Duong quantum distance - 0.18811594547192254 - Classical distance - 0.18834526350398864
# Duong quantum distance - 0.5208972948322484 - Classical distance - 0.5229726085982854
# Duong quantum distance - 0.2811558355127472 - Classical distance - 0.27858876522553283
# Duong quantum distance - 0.73292816833927 - Classical distance - 0.7321974264809292
# Duong quantum distance - 0.8134432375644863 - Classical distance - 0.8103057807695202
# Duong quantum distance - 0.30747546230430073 - Classical distance - 0.30112321347076665
# Duong quantum distance - 0.4091419087557722 - Classical distance - 0.4084223748800028
# Duong quantum distance - 0.33092586303591937 - Classical distance - 0.33217798411235994
# Duong quantum distance - 0.27398350923013487 - Classical distance - 0.2743841274016304
# Duong quantum distance - 0.42090143221915205 - Classical distance - 0.4217429500759132
# Duong quantum distance - 0.2951387840804461 - Classical distance - 0.29291243406174533
# Duong quantum distance - 0.3423986039552034 - Classical distance - 0.33781004784401697
# Duong quantum distance - 0.7079169657052387 - Classical distance - 0.707239908072239
# Duong quantum distance - 0.37068528509878973 - Classical distance - 0.37027343321999673
# Duong quantum distance - 0.49064697582479855 - Classical distance - 0.4906948186345696
# Duong quantum distance - 0.2512623454142896 - Classical distance - 0.2542320581678522
# Duong quantum distance - 0.6498418271204198 - Classical distance - 0.6468065420233942
# Duong quantum distance - 0.42610555704174885 - Classical distance - 0.4320459712938246
# Duong quantum distance - 0.2735069404423093 - Classical distance - 0.27721206939409765
# Duong quantum distance - 0.5030946945238233 - Classical distance - 0.5049590767927711
# Duong quantum distance - 0.21602811730268423 - Classical distance - 0.21627461766176106
# Duong quantum distance - 0.5164058952546027 - Classical distance - 0.515326071370246
# Duong quantum distance - 0.08814151190858929 - Classical distance - 0.09268897314542691
# Duong quantum distance - 0.3790286010462543 - Classical distance - 0.3707751473877575
# Duong quantum distance - 0.05296414099817657 - Classical distance - 0.05392231142045144
# Duong quantum distance - 0.07675768476140825 - Classical distance - 0.07895632811627448
# Duong quantum distance - 0.11684840090173179 - Classical distance - 0.11688533654325466
# Duong quantum distance - 0.11842081294190723 - Classical distance - 0.12045344553069476
# Duong quantum distance - 0.4228350869899225 - Classical distance - 0.42495808492784515
# Duong quantum distance - 0.14296280214559662 - Classical distance - 0.14109543993221638
# Duong quantum distance - 0.08372587551264213 - Classical distance - 0.08157224088986614
# Duong quantum distance - 0.16917752782976228 - Classical distance - 0.1685756606899583
# Duong quantum distance - 0.2046662009372563 - Classical distance - 0.2022163094296432
# Duong quantum distance - 0.11005863955718348 - Classical distance - 0.10963793413467546
# Duong quantum distance - 0.16854859430423805 - Classical distance - 0.16986089986002714
# Duong quantum distance - 0.2285167132347948 - Classical distance - 0.2254776638872594
# Duong quantum distance - 0.2135095148933508 - Classical distance - 0.21784859435620915
# Duong quantum distance - 0.034563777025606285 - Classical distance - 0.035898588213854596
# Duong quantum distance - 0.15451261643971398 - Classical distance - 0.15408252859545224
# Duong quantum distance - 0.13649677598849277 - Classical distance - 0.12996700936400593
# Duong quantum distance - 0.29123406317012485 - Classical distance - 0.2928448643116846
# Duong quantum distance - 0.2667479703721689 - Classical distance - 0.2692996427165625
# Duong quantum distance - 0.24046940434450995 - Classical distance - 0.24009959947146572
# Duong quantum distance - 0.050923018967834854 - Classical distance - 0.049559780807538714
# Duong quantum distance - 0.26703255836511736 - Classical distance - 0.2646444235200152
# Duong quantum distance - 0.17222429036414702 - Classical distance - 0.16746752151919894
# Duong quantum distance - 0.15385842718690693 - Classical distance - 0.15279085566699038
# Duong quantum distance - 0.07605446616373351 - Classical distance - 0.07793056816185329
# Duong quantum distance - 0.0 - Classical distance - 0.0
# Duong quantum distance - 0.17132987914307019 - Classical distance - 0.1713357264126005
# Duong quantum distance - 0.04435799710121799 - Classical distance - 0.046703682423357
# Duong quantum distance - 0.17733857641849896 - Classical distance - 0.17451541089861833
# Duong quantum distance - 0.2249798914920746 - Classical distance - 0.22207984186007557
# Duong quantum distance - 0.24165592830756896 - Classical distance - 0.2397848875156979
# Duong quantum distance - 0.16346107486678968 - Classical distance - 0.15985718168902655
# Duong quantum distance - 0.018165287715291578 - Classical distance - 0.020976818479527443
# Duong quantum distance - 0.19598303036822842 - Classical distance - 0.20014325992983553
# Duong quantum distance - 0.1542807564572573 - Classical distance - 0.15363775186414294
# Duong quantum distance - 0.06038898739206692 - Classical distance - 0.06013587057199687
# Duong quantum distance - 0.2547660985135266 - Classical distance - 0.25099887641799506
# Duong quantum distance - 0.05967693491080181 - Classical distance - 0.056234249360683074
# Duong quantum distance - 0.4947941002941956 - Classical distance - 0.4912048932477522
# Duong quantum distance - 0.19002278638451225 - Classical distance - 0.18800819730877397
# Duong quantum distance - 0.11049816170492682 - Classical distance - 0.11919848855191423
# Duong quantum distance - 0.4175552022802812 - Classical distance - 0.4203676107205336
# Duong quantum distance - 0.22983227100635234 - Classical distance - 0.2326940949424629
# Duong quantum distance - 0.0633377717254464 - Classical distance - 0.06129844217560373
# Duong quantum distance - 0.12020277494423563 - Classical distance - 0.12646617097503873
# Duong quantum distance - 0.26541383390529066 - Classical distance - 0.2662519352090872
# Duong quantum distance - 0.273727909489581 - Classical distance - 0.27002957168956954
# Duong quantum distance - 0.1936304486590347 - Classical distance - 0.19947136265212714
# Duong quantum distance - 0.2862235126930917 - Classical distance - 0.28906006637722303
# Duong quantum distance - 0.7819107427955593 - Classical distance - 0.7810110424226634
# Duong quantum distance - 0.8044020336162554 - Classical distance - 0.8051668154239824
# Duong quantum distance - 0.8151550549064758 - Classical distance - 0.8160038829409897
# Duong quantum distance - 0.8279355090990318 - Classical distance - 0.8279946803136446
# Duong quantum distance - 0.754947993219238 - Classical distance - 0.7539021756294285
# Duong quantum distance - 0.7472821715915574 - Classical distance - 0.7475269012623587
# Duong quantum distance - 0.6802448710742083 - Classical distance - 0.6802428309362754
# Duong quantum distance - 0.8492282770608648 - Classical distance - 0.850028035002229
# Duong quantum distance - 0.8263416006132625 - Classical distance - 0.8269281803028157
# Duong quantum distance - 0.7896891523089499 - Classical distance - 0.7902140119231899
# Duong quantum distance - 0.7736139375745151 - Classical distance - 0.7727898387820041
# Duong quantum distance - 0.8391373991964451 - Classical distance - 0.84176897337538
# Duong quantum distance - 0.8558092195629533 - Classical distance - 0.8558751661484411
# Duong quantum distance - 0.7741067379885249 - Classical distance - 0.774534608528449
# Duong quantum distance - 0.7920197077316565 - Classical distance - 0.7919608796785542
# Duong quantum distance - 0.7661969153840862 - Classical distance - 0.7638248960767166
# Duong quantum distance - 0.9172166908457347 - Classical distance - 0.9172902222131006
# Duong quantum distance - 0.9201087007371646 - Classical distance - 0.9200998205401927
# Duong quantum distance - 0.6951967622423983 - Classical distance - 0.6934864481130136
# Duong quantum distance - 0.7670885420722581 - Classical distance - 0.7651436579709502
# Duong quantum distance - 0.784294699443418 - Classical distance - 0.7835246858930749
# Duong quantum distance - 0.7720295697892693 - Classical distance - 0.7739637640040685
# Duong quantum distance - 0.7778004358640594 - Classical distance - 0.7782375314980275
# Duong quantum distance - 0.7204356031773262 - Classical distance - 0.7187282724381499
# Duong quantum distance - 0.7333707184085367 - Classical distance - 0.7354682358595175
# Duong quantum distance - 0.7604308417657505 - Classical distance - 0.7600583409450171
# Duong quantum distance - 0.6598125738569743 - Classical distance - 0.6594349032761267
# Duong quantum distance - 0.8994741232538852 - Classical distance - 0.898466432636235
# Duong quantum distance - 0.7680625674089817 - Classical distance - 0.7684589888133405
# Duong quantum distance - 0.724383273112583 - Classical distance - 0.7250258292051851
# Duong quantum distance - 0.8127536331385372 - Classical distance - 0.8128596215790753
# Duong quantum distance - 0.7584686254167061 - Classical distance - 0.7585683416227573
# Duong quantum distance - 0.7705636749403331 - Classical distance - 0.7710034250374241
# Duong quantum distance - 0.81142395273726 - Classical distance - 0.8114111161452945
# Duong quantum distance - 0.9159878487096375 - Classical distance - 0.9143999066454204
# Duong quantum distance - 0.8734065186927281 - Classical distance - 0.8741544452431005
# Duong quantum distance - 0.8999053618350525 - Classical distance - 0.9020093843814353
# Duong quantum distance - 0.8086190510030757 - Classical distance - 0.8075985110345204
# Duong quantum distance - 0.790722991103552 - Classical distance - 0.7915171597491403
# Duong quantum distance - 0.7985558163588451 - Classical distance - 0.7983672530021848
# Duong quantum distance - 0.7915569666803235 - Classical distance - 0.7907315404900427
# Duong quantum distance - 0.8273705628263763 - Classical distance - 0.830037995953655
# Duong quantum distance - 0.7828557183342999 - Classical distance - 0.7822943518561498
# Duong quantum distance - 0.8068563765040173 - Classical distance - 0.8062918807541346
# Duong quantum distance - 0.7725242661549128 - Classical distance - 0.7725162549027264
# Duong quantum distance - 0.8216695817565607 - Classical distance - 0.8210991990424044
# Duong quantum distance - 0.7981860779136813 - Classical distance - 0.7996251559407597
# Duong quantum distance - 0.8135120025172775 - Classical distance - 0.8149368468325476
# Duong quantum distance - 0.7710991263856306 - Classical distance - 0.7684438140148105
# Duong quantum distance - 0.7973387958795483 - Classical distance - 0.7972537355378863
# Duong same count: 149 and different count: 0
# Duong quantum distance - 0.3577514046279944 - Classical distance - 0.35877921056385326
# Duong quantum distance - 0.6098967072085091 - Classical distance - 0.6096042316641053
# Duong quantum distance - 0.5079397171067747 - Classical distance - 0.5085719409504774
# Duong quantum distance - 0.3905149532942835 - Classical distance - 0.3880483612628335
# Duong quantum distance - 0.6051449997353207 - Classical distance - 0.6086726802159456
# Duong quantum distance - 0.7404692386300057 - Classical distance - 0.7396649266502195
# Duong quantum distance - 0.7134790189491567 - Classical distance - 0.7122878705319842
# Duong quantum distance - 0.33979416433956233 - Classical distance - 0.3323267369866293
# Duong quantum distance - 0.6447812852946451 - Classical distance - 0.6480767873176124
# Duong quantum distance - 0.6756833540002055 - Classical distance - 0.67928100969614
# Duong quantum distance - 0.6354425865886031 - Classical distance - 0.6284545182955293
# Duong quantum distance - 0.34631049111025947 - Classical distance - 0.3530321809085847
# Duong quantum distance - 0.485440186256738 - Classical distance - 0.4902037343450094
# Duong quantum distance - 0.6576693014214814 - Classical distance - 0.6615615617054018
# Duong quantum distance - 0.8431234784641285 - Classical distance - 0.8464948836205174
# Duong quantum distance - 0.28996808640622446 - Classical distance - 0.2918712751589807
# Duong quantum distance - 0.32430586470009615 - Classical distance - 0.32583327868317
# Duong quantum distance - 0.5572090103568 - Classical distance - 0.5520118357206184
# Duong quantum distance - 0.9961802265102118 - Classical distance - 0.991947996852998
# Duong quantum distance - 0.6852903018843272 - Classical distance - 0.6799763141774942
# Duong quantum distance - 0.5871808464512498 - Classical distance - 0.5850938257122937
# Duong quantum distance - 0.5270624114692535 - Classical distance - 0.5270656478197108
# Duong quantum distance - 0.38109839757168146 - Classical distance - 0.37690247094147955
# Duong quantum distance - 0.3473434367094059 - Classical distance - 0.3517995893294338
# Duong quantum distance - 0.6834377991685631 - Classical distance - 0.6790649309425902
# Duong quantum distance - 0.6612265537742616 - Classical distance - 0.654492668418304
# Duong quantum distance - 0.36362301237036365 - Classical distance - 0.3644202874605858
# Duong quantum distance - 0.7988792929420293 - Classical distance - 0.8050134866310213
# Duong quantum distance - 0.30386633443530053 - Classical distance - 0.31454107455728536
# Duong quantum distance - 0.7127505188352772 - Classical distance - 0.712391174404391
# Duong quantum distance - 0.2681879599070955 - Classical distance - 0.26549290882912957
# Duong quantum distance - 0.889859143323735 - Classical distance - 0.8839083413662381
# Duong quantum distance - 1.0088417426869747 - Classical distance - 1.0145256841104884
# Duong quantum distance - 0.4909621376826743 - Classical distance - 0.4888506528358389
# Duong quantum distance - 0.5985093644733513 - Classical distance - 0.5984365003419035
# Duong quantum distance - 0.46882984314913273 - Classical distance - 0.46541231360488505
# Duong quantum distance - 0.33614395097798005 - Classical distance - 0.3364870159258602
# Duong quantum distance - 0.6089032703703775 - Classical distance - 0.6044486036588032
# Duong quantum distance - 0.4417484386065348 - Classical distance - 0.44131102524571003
# Duong quantum distance - 0.5408894436702476 - Classical distance - 0.5379386974973964
# Duong quantum distance - 0.9095742637957466 - Classical distance - 0.9064268291246228
# Duong quantum distance - 0.5020427105930471 - Classical distance - 0.497960008060335
# Duong quantum distance - 0.6705749767578587 - Classical distance - 0.6702740915603036
# Duong quantum distance - 0.1352376566008797 - Classical distance - 0.1363038571096469
# Duong quantum distance - 0.8382280329686054 - Classical distance - 0.82697233994825
# Duong quantum distance - 0.6045334931537968 - Classical distance - 0.6051443094870007
# Duong quantum distance - 0.44995531861191457 - Classical distance - 0.44953646688083443
# Duong quantum distance - 0.6883733340917553 - Classical distance - 0.6866386045067867
# Duong quantum distance - 0.33705356500120665 - Classical distance - 0.3323267369866293
# Duong quantum distance - 0.698276805147964 - Classical distance - 0.6991384419670723
# Duong quantum distance - 0.13940529674852645 - Classical distance - 0.13568360421402675
# Duong quantum distance - 0.18758002425592704 - Classical distance - 0.18978292988146303
# Duong quantum distance - 0.2498490437222024 - Classical distance - 0.2503401239047602
# Duong quantum distance - 0.17339374532921562 - Classical distance - 0.1722366198468781
# Duong quantum distance - 0.2050636853399588 - Classical distance - 0.2058341638036862
# Duong quantum distance - 0.08876459553334241 - Classical distance - 0.09004066178886781
# Duong quantum distance - 0.22120069160214953 - Classical distance - 0.2223306021402591
# Duong quantum distance - 0.07430127442456083 - Classical distance - 0.07239329708820656
# Duong quantum distance - 0.2891597643287268 - Classical distance - 0.2892095797099346
# Duong quantum distance - 0.036769546334925685 - Classical distance - 0.04113343239768341
# Duong quantum distance - 0.023595239360880104 - Classical distance - 0.020538976268167274
# Duong quantum distance - 0.19483241606421958 - Classical distance - 0.19490205897715684
# Duong quantum distance - 0.1703758031075655 - Classical distance - 0.16912878850443022
# Duong quantum distance - 0.4365389498642921 - Classical distance - 0.4344173471830566
# Duong quantum distance - 0.4161004286471204 - Classical distance - 0.41702345437237476
# Duong quantum distance - 0.1895985935830069 - Classical distance - 0.185690894238462
# Duong quantum distance - 0.28458962836463364 - Classical distance - 0.28710686672937363
# Duong quantum distance - 0.10767531325820293 - Classical distance - 0.10771274444896209
# Duong quantum distance - 0.09456498548946532 - Classical distance - 0.09369213291978701
# Duong quantum distance - 0.06349577881283147 - Classical distance - 0.06229595426877187
# Duong quantum distance - 0.11348246915645942 - Classical distance - 0.1144942436669893
# Duong quantum distance - 0.25805716424600667 - Classical distance - 0.25536246035720245
# Duong quantum distance - 0.4649385345237244 - Classical distance - 0.46391158024886453
# Duong quantum distance - 0.3695086202723031 - Classical distance - 0.36630227558333467
# Duong quantum distance - 0.3630668466846421 - Classical distance - 0.3609877971669292
# Duong quantum distance - 0.28064921300322326 - Classical distance - 0.281995137140354
# Duong quantum distance - 0.20984619605612098 - Classical distance - 0.20898155629905263
# Duong quantum distance - 0.2695306347845432 - Classical distance - 0.27409313445365674
# Duong quantum distance - 0.19257335558737862 - Classical distance - 0.19301209011700354
# Duong quantum distance - 0.389389198320453 - Classical distance - 0.3819257738606231
# Duong quantum distance - 0.03412052969577535 - Classical distance - 0.033663960596291856
# Duong quantum distance - 0.2342943875356385 - Classical distance - 0.23123596306912883
# Duong quantum distance - 0.10906359240608116 - Classical distance - 0.10980791673483783
# Duong quantum distance - 0.21811124172806387 - Classical distance - 0.2175268912799199
# Duong quantum distance - 0.4094430317341317 - Classical distance - 0.40664773542507454
# Duong quantum distance - 0.16516853210012158 - Classical distance - 0.1657972120376737
# Duong quantum distance - 0.2654888631119094 - Classical distance - 0.2668833601811595
# Duong quantum distance - 0.06041848964929774 - Classical distance - 0.05996879756459236
# Duong quantum distance - 0.2512717720258068 - Classical distance - 0.2534093099233815
# Duong quantum distance - 0.2850403739360371 - Classical distance - 0.28261834286616067
# Duong quantum distance - 0.039809667734314165 - Classical distance - 0.03798804038525888
# Duong quantum distance - 0.33015374127745517 - Classical distance - 0.32816779614118896
# Duong quantum distance - 0.21700736232383605 - Classical distance - 0.22405990493474323
# Duong quantum distance - 0.43249515813057066 - Classical distance - 0.44030107461453877
# Duong quantum distance - 0.15002402244574264 - Classical distance - 0.14847867266584433
# Duong quantum distance - 0.32123860175046953 - Classical distance - 0.321844008891948
# Duong quantum distance - 0.08464952261124961 - Classical distance - 0.08619863393579248
# Duong quantum distance - 0.4739272504633474 - Classical distance - 0.4782411080347047
# Duong quantum distance - 0.40370089162522094 - Classical distance - 0.40546163331179813
# Duong quantum distance - 0.4949997078784835 - Classical distance - 0.4972287493119736
# Duong quantum distance - 0.7093967948290137 - Classical distance - 0.7097694860950498
# Duong quantum distance - 0.7804376169879744 - Classical distance - 0.7814821614928058
# Duong quantum distance - 0.7220695775206002 - Classical distance - 0.7216582411042449
# ...
# Khan quantum distance - 0.10579824973244516 - Classical distance - 0.09041872351133558
# Khan quantum distance - 0.07408173569402413 - Classical distance - 0.08769534685337559
# Khan quantum distance - 0.11988251366080382 - Classical distance - 0.1362038305257088
# Khan quantum distance - 0.3160266394868588 - Classical distance - 0.34978862407511246
# Khan quantum distance - 0.2614649688162133 - Classical distance - 0.2814766788648095
# Khan quantum distance - 0.0362608111036659 - Classical distance - 0.09990567912460503
# Khan quantum distance - 0.1484492159454983 - Classical distance - 0.14899195362762527
# Khan quantum distance - 0.10061441746159305 - Classical distance - 0.12464911391983362
# Khan quantum distance - 0.0 - Classical distance - 0.014313486834773034
# Khan quantum distance - 0.05489215526444159 - Classical distance - 0.05071441493931003
# Khan quantum distance - 0.0 - Classical distance - 0.058429325277144624
# Khan quantum distance - 0.15721887711096647 - Classical distance - 0.16555833880437154
# Khan quantum distance - 0.05438619464770145 - Classical distance - 0.04052717806744268
# Khan quantum distance - 0.02507926534403722 - Classical distance - 0.11945561960053337
# Khan quantum distance - 0.0 - Classical distance - 0.12136590975029471
# Khan quantum distance - 0.10862730466575954 - Classical distance - 0.11918455582251741
# Khan quantum distance - 0.045562233074707456 - Classical distance - 0.06938602685817796
# Khan quantum distance - 0.12259109231375469 - Classical distance - 0.15068362073978084
# Khan quantum distance - 0.24942812317855162 - Classical distance - 0.2399411436725193
# Khan quantum distance - 0.03860889792311523 - Classical distance - 0.04126140517318008
# Khan quantum distance - 0.2279815207689871 - Classical distance - 0.22889379208931576
# Khan quantum distance - 0.43889169085955065 - Classical distance - 0.451559387700391
# Khan quantum distance - 0.3010186301845153 - Classical distance - 0.3121776332695948
# Khan quantum distance - 0.23583606289675318 - Classical distance - 0.2745638322512379
# Khan quantum distance - 0.17637143532537666 - Classical distance - 0.18918649838672144
# Khan quantum distance - 0.0 - Classical distance - 0.04142531626277795
# Khan quantum distance - 0.18852687722360967 - Classical distance - 0.1500455848434229
# Khan quantum distance - 0.12876767264437397 - Classical distance - 0.138494800516736
# Khan quantum distance - 0.27246321370451976 - Classical distance - 0.2753006696709434
# Khan quantum distance - 0.027634936378661514 - Classical distance - 0.013610959852554503
# Khan quantum distance - 0.05653779405723591 - Classical distance - 0.0692857853760543
# Khan quantum distance - 0.2447920577872141 - Classical distance - 0.23615369974728903
# Khan quantum distance - 0.04016318428139602 - Classical distance - 0.07165353551080175
# Khan quantum distance - 0.15025469801912772 - Classical distance - 0.17515305795983846
# Khan quantum distance - 0.10314726465009164 - Classical distance - 0.1304277756102586
# Khan quantum distance - 0.19394053113971044 - Classical distance - 0.17290337863797953
# Khan quantum distance - 0.062363600466848274 - Classical distance - 0.04087994652253704
# Khan quantum distance - 0.09222924122772956 - Classical distance - 0.14949875251458666
# Khan quantum distance - 0.07283931376680755 - Classical distance - 0.10937373343563847
# Khan quantum distance - 0.019598979327931886 - Classical distance - 0.02074231871222769
# Khan quantum distance - 0.237387018898803 - Classical distance - 0.22773616316073372
# Khan quantum distance - 0.0 - Classical distance - 0.11679689987270393
# Khan quantum distance - 0.0700291793981586 - Classical distance - 0.2329165691298771
# Khan quantum distance - 0.04843957167174858 - Classical distance - 0.2074717670010756
# Khan quantum distance - 0.2196694621691372 - Classical distance - 0.22848016505336335
# Khan quantum distance - 0.03897989082865525 - Classical distance - 0.140930371871781
# Khan quantum distance - 0.0 - Classical distance - 0.18321500117144077
# Khan quantum distance - 0.053773590619691745 - Classical distance - 0.12047290874453333
# Khan quantum distance - 0.06988418983338268 - Classical distance - 0.15879054822924535
# Khan quantum distance - 0.018777358340008935 - Classical distance - 0.029066677927220938
# Khan quantum distance - 0.07107957142301403 - Classical distance - 0.15408479036878925
# Khan quantum distance - 0.028007091857914036 - Classical distance - 0.34790123629208536
# Khan quantum distance - 0.2496944575081189 - Classical distance - 0.25177839777807237
# Khan quantum distance - 0.11578023605447159 - Classical distance - 0.1824347788089091
# Khan quantum distance - 0.09786149513931758 - Classical distance - 0.15369653352284188
# Khan quantum distance - 0.3312068662359178 - Classical distance - 0.5047553860027395
# Khan quantum distance - 0.0 - Classical distance - 0.19830705861590253
# Khan quantum distance - 0.03591794845960812 - Classical distance - 0.07898214554434746
# Khan quantum distance - 0.10828049575052551 - Classical distance - 0.1356804723039111
# Khan quantum distance - 0.04460963974154859 - Classical distance - 0.13408994702108948
# Khan quantum distance - 0.13691209363567405 - Classical distance - 0.16194617027833177
# Khan quantum distance - 0.10634884484982965 - Classical distance - 0.1744266532273786
# Khan quantum distance - 0.09654959860272648 - Classical distance - 0.14942663992377622
# Khan quantum distance - 0.15201253402240697 - Classical distance - 0.1682344913399269
# Khan quantum distance - 0.0 - Classical distance - 0.3249844182693161
# Khan quantum distance - 0.22063775823426346 - Classical distance - 0.22497503525954288
# Khan quantum distance - 0.05383128861090176 - Classical distance - 0.20553275094105528
# Khan quantum distance - 0.39370433573643754 - Classical distance - 0.402417813615677
# Khan quantum distance - 0.061007224182494234 - Classical distance - 0.43969240874451615
# Khan quantum distance - 0.30283141965695537 - Classical distance - 0.5162054024127399
# Khan quantum distance - 0.0 - Classical distance - 0.021461084799047455
# Khan quantum distance - 0.036944951655329746 - Classical distance - 0.09086139138613666
# Khan quantum distance - 0.18587865119848931 - Classical distance - 0.17929976295438607
# Khan quantum distance - 0.2957861333664928 - Classical distance - 0.30549730695446137
# Khan quantum distance - 0.0 - Classical distance - 0.10706668407188971
# Khan quantum distance - 0.1449733409918558 - Classical distance - 0.14206522548320202
# Khan quantum distance - 0.06130566315376997 - Classical distance - 0.06062920045700219
# Khan quantum distance - 0.2102748306509382 - Classical distance - 0.4003536061155721
# Khan quantum distance - 0.18813600793179464 - Classical distance - 0.2017575069100262
# Khan quantum distance - 0.0 - Classical distance - 0.1765885874879113
# Khan quantum distance - 0.4730967529833926 - Classical distance - 0.48719059098066875
# Khan quantum distance - 0.027560661082510346 - Classical distance - 0.33017226296596086
# Khan quantum distance - 0.044660036553764035 - Classical distance - 0.13097110573049064
# Khan quantum distance - 0.07086020217873112 - Classical distance - 0.08288479451045742
# Khan quantum distance - 0.0 - Classical distance - 0.18894482120120074
# Khan quantum distance - 0.21283868280667728 - Classical distance - 0.22848016505336335
# Khan quantum distance - 0.0 - Classical distance - 0.19811429198861466
# Khan quantum distance - 0.37095897508739006 - Classical distance - 0.41048499435870384
# Khan quantum distance - 0.6950912737197241 - Classical distance - 0.6856143721456577
# Khan quantum distance - 0.10249852001414966 - Classical distance - 0.3090025931550657
# Khan quantum distance - 0.30585075112923055 - Classical distance - 0.39262554732861404
# Khan quantum distance - 0.3143199587508651 - Classical distance - 0.4133610318978478
# Khan quantum distance - 0.41428462814807027 - Classical distance - 0.4298159270133015
# Khan quantum distance - 0.73344129910809 - Classical distance - 0.7304935342041334
# Khan quantum distance - 0.4469051243682206 - Classical distance - 0.4511907414179753
# Khan quantum distance - 0.0361401663167637 - Classical distance - 0.26476148594023313
# Khan quantum distance - 0.4591527126562262 - Classical distance - 0.4676269517195469
# Khan quantum distance - 0.5019719516353244 - Classical distance - 0.4949828505055437
# Khan quantum distance - 0.32266674518072574 - Classical distance - 0.4116298004812857
# Khan quantum distance - 0.37669507731609086 - Classical distance - 0.37806067730873927
# Khan quantum distance - 0.0875528339502661 - Classical distance - 0.16535609172857887
# Khan quantum distance - 0.16564676392255437 - Classical distance - 0.2661420226937844
# Khan quantum distance - 0.24603124375663832 - Classical distance - 0.3527300825578196
# Khan quantum distance - 0.21653636704850282 - Classical distance - 0.23621886676393483
# Khan quantum distance - 0.43978331874085014 - Classical distance - 0.44737291751043606
# Khan quantum distance - 0.602454508942248 - Classical distance - 0.5999049409418049
# Khan quantum distance - 0.5709139127189385 - Classical distance - 0.5704206455478031
# Khan quantum distance - 0.5782403155946763 - Classical distance - 0.5577845586179911
# Khan quantum distance - 0.1206557119535521 - Classical distance - 0.2689130961043709
# Khan quantum distance - 0.018017007222070447 - Classical distance - 0.06642569237337237
# Khan quantum distance - 0.03290740154256011 - Classical distance - 0.15144111796596962
# Khan quantum distance - 0.04605856494597211 - Classical distance - 0.22091127130574703
# Khan quantum distance - 0.029138946492918667 - Classical distance - 0.2807565658377899
# Khan quantum distance - 0.19284594545830705 - Classical distance - 0.31784838039298086
# Khan quantum distance - 0.25447279395102074 - Classical distance - 0.26671028958136916
# Khan quantum distance - 0.2334020059253975 - Classical distance - 0.3580866523731825
# Khan quantum distance - 0.0 - Classical distance - 0.16677650943247335
# Khan quantum distance - 0.5356568432309485 - Classical distance - 0.5294137793113838
# Khan quantum distance - 0.38520172838172295 - Classical distance - 0.38849845278588174
# Khan quantum distance - 0.4803216824134656 - Classical distance - 0.4777053725223585
# Khan quantum distance - 0.17965833442914533 - Classical distance - 0.3220961321071561
# Khan quantum distance - 0.12650836271189814 - Classical distance - 0.22226583403743105
# Khan quantum distance - 0.49219046433768443 - Classical distance - 0.46492252801015943
# Khan quantum distance - 0.0995494996503715 - Classical distance - 0.25975949464032805
# Khan quantum distance - 0.5310764885002195 - Classical distance - 0.5316113657208816
# Khan quantum distance - 0.08970483736059177 - Classical distance - 0.3067412224887994
# Khan quantum distance - 0.775807790970675 - Classical distance - 0.7754623171011618
# Khan quantum distance - 0.509316166045557 - Classical distance - 0.49709255752124326
# Khan quantum distance - 0.015255416926577468 - Classical distance - 0.22310890246825085
# Khan quantum distance - 0.7241658163699405 - Classical distance - 0.7303781904483235
# Khan quantum distance - 0.13087745793394115 - Classical distance - 0.20594257820394593
# Khan quantum distance - 0.3173744075055788 - Classical distance - 0.37486046449171445
# Khan quantum distance - 0.08152777875760382 - Classical distance - 0.1915882413018052
# Khan quantum distance - 0.5288934399826057 - Classical distance - 0.536103258576289
# Khan quantum distance - 0.1047388382194137 - Classical distance - 0.13424831705967158
# Khan quantum distance - 0.11492410723791914 - Classical distance - 0.22671357957201646
# Khan quantum distance - 0.17101166754083819 - Classical distance - 0.19901446583122362
# Khan quantum distance - 1.081330807804508 - Classical distance - 1.065278516039054
# Khan quantum distance - 1.0763911383360676 - Classical distance - 1.0548989523335575
# Khan quantum distance - 1.1365527120923926 - Classical distance - 1.1120028056184972
# Khan quantum distance - 1.095372042793093 - Classical distance - 1.0760721790462493
# Khan quantum distance - 1.071570225422656 - Classical distance - 1.0564790826602293
# Khan quantum distance - 1.0035053463336452 - Classical distance - 0.9913757316823715
# Khan quantum distance - 0.9514755784254406 - Classical distance - 0.9495581223872932
# Khan quantum distance - 1.1801992732525148 - Classical distance - 1.148409956472557
# Khan quantum distance - 1.1782111914714022 - Classical distance - 1.1447758221459599
# Khan quantum distance - 1.0777500179459194 - Classical distance - 1.0616872083290345
# Khan quantum distance - 1.0640874300637726 - Classical distance - 1.048878582838458
# Khan quantum distance - 1.1794681564015226 - Classical distance - 1.147725052759272
# Khan quantum distance - 1.1540850085392913 - Classical distance - 1.1243481407896856
# Khan quantum distance - 1.047819929562471 - Classical distance - 1.0337166343118274
# Khan quantum distance - 1.0999995738130017 - Classical distance - 1.0815794115464508
# Khan quantum distance - 1.076479545101209 - Classical distance - 1.0605633248972732
# Khan quantum distance - 1.1607955314598153 - Classical distance - 1.1228987188309287
# Khan quantum distance - 1.1822969733615492 - Classical distance - 1.1452939534777786
# Khan quantum distance - 0.9638484599246804 - Classical distance - 0.9608125858173386
# Khan quantum distance - 1.079795228372471 - Classical distance - 1.0634551768305764
# Khan quantum distance - 1.0974883032531992 - Classical distance - 1.0784780816361554
# Khan quantum distance - 1.0635358277937221 - Classical distance - 1.0477767190865652
# Khan quantum distance - 1.0592563179996093 - Classical distance - 1.0452195148939682
# Khan quantum distance - 1.0036271795185232 - Classical distance - 0.9963280429384217
# Khan quantum distance - 1.0481221676133343 - Classical distance - 1.0357517669941037
# Khan quantum distance - 1.0576446566164148 - Classical distance - 1.0426998028571843
# Khan quantum distance - 0.9452107840279309 - Classical distance - 0.9412604737895041
# Khan quantum distance - 1.2115908547736511 - Classical distance - 1.1731468793852187
# Khan quantum distance - 1.0345507456278966 - Classical distance - 1.0217154295351227
# Khan quantum distance - 1.0003824137217996 - Classical distance - 0.9936281120035072
# Khan quantum distance - 1.0797955819969132 - Classical distance - 1.0599049051604255
# Khan quantum distance - 0.9990004332295483 - Classical distance - 0.9833818847158509
# Khan quantum distance - 1.054630965643491 - Classical distance - 1.039947073438162
# Khan quantum distance - 1.053978690503682 - Classical distance - 1.0398063367135262
# Khan quantum distance - 1.1100140606747944 - Classical distance - 1.0893248239985114
# Khan quantum distance - 1.1157828661522677 - Classical distance - 1.085293619645188
# Khan quantum distance - 1.2525897735569054 - Classical distance - 1.20800953621044
# Khan quantum distance - 1.1338195979935821 - Classical distance - 1.1094880915620233
# Khan quantum distance - 1.0926102745498427 - Classical distance - 1.0739606479915862
# Khan quantum distance - 1.064017281107369 - Classical distance - 1.0449863702892874
# Khan quantum distance - 1.107578876808647 - Classical distance - 1.0872474040818791
# Khan quantum distance - 1.1690907151084866 - Classical distance - 1.1393309111462977
# Khan quantum distance - 1.0794061312363645 - Classical distance - 1.060584063197654
# Khan quantum distance - 1.112554424789513 - Classical distance - 1.0922042029922416
# Khan quantum distance - 1.0136875016364297 - Classical distance - 0.998221802271049
# Khan quantum distance - 1.1076910832180085 - Classical distance - 1.0864823636299332
# Khan quantum distance - 1.1229360822082164 - Classical distance - 1.1002283176299281
# Khan quantum distance - 1.1336480539305382 - Classical distance - 1.1093619632518406
# Khan quantum distance - 1.086549814964116 - Classical distance - 1.0695129525786973
# Khan quantum distance - 1.0834786576226123 - Classical distance - 1.0668371981088538
# Khan same count: 142 and different count: 7
# Khan's iteration count is: 8
